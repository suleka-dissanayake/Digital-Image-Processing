# %% [markdown]
# Log Transformation

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("images.jpg", cv2.IMREAD_GRAYSCALE)
img_float = img.astype(np.float32)
img_float = np.clip(img_float, 0, 255)

# %%
c = 255.0 / np.log(1+255)
log_transformed = c * np.log1p(img_float32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14828\3614131731.py in <module>
#       1 c = 255.0 / np.log(1+255)
# ----> 2 log_transformed = c * np.log1p(img_float32)
#
# NameError: name 'img_float32' is not defined

# %%
log_transformed = c * np.log(1+img)
log_transformed = np.clip(log_transformed, 0, 255)
log_transformed = log_transformed.astype(np.uint8)
# Out:
# C:\Users\2022ict81\AppData\Local\Temp\ipykernel_14828\862154746.py:1: RuntimeWarning: divide by zero encountered in log
#   log_transformed = c * np.log(1+img)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img.astype(np.uint8), cmap='gray')
plt.title('Original')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(log_transformed, cmap='gray')
plt.title('Log Transformed')
# Out:
# Text(0.5, 1.0, 'Log Transformed')

# %% [markdown]
# Log Transformation using OpenCV built in function

# %%
img_plus_one = img + 1
img_plus_one = img_plus_one.astype(np.float32)

# %%
log_cv2_raw = cv2.log(img_plus_one)
log_transformed_cv2 = c * log_cv2_raw
log_transformed_cv2 = np.clip(log_transformed_cv2, 0, 255)
log_transformed_cv2 = log_transformed_cv2.astype(np.uint8)

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,2,1)
plt.imshow(img.astype(np.uint8), cmap='gray')
plt.title("Log Transformation (manual)")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(log_transformed, cnap='gray')
plt.title("Log Transformation (manual)")
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14828\1613009274.py in <module>
#       6
#       7 plt.subplot(1,2,2)
# ----> 8 plt.imshow(log_transformed, cnap='gray')
#       9 plt.title("Log Transformation (manual)")
#      10 plt.axis('off')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2650         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2651         resample=None, url=None, data=None, **kwargs):
# -> 2652     __ret = gca().imshow(
#    2653         X, cmap=cmap, norm=norm, aspect=aspect,
#    2654         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5473             aspect = rcParams['image.aspect']
#    5474         self.set_aspect(aspect)
# -> 5475         im = mimage.AxesImage(self, cmap, norm, interpolation,
#    5476                               origin, extent, filternorm=filternorm,
#    5477                               filterrad=filterrad, resample=resample,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in __init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     927         self._extent = extent
#     928
# --> 929         super().__init__(
#     930             ax,
#     931             cmap=cmap,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in __init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     258         self._imcache = None
#     259
# --> 260         self.update(kwargs)
#     261
#     262     def __getstate__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'AxesImage' object has no property 'cnap'

# %% [markdown]
# Gamma Transformation

# %%
normalized = img / 255.0

# %%
gamma_04 = np.power(normalized, 0.4) * 255
gamma_04 = np.clip(gamma_04, 0, 255)
gamma_04 = gamma_04.astype(np.uint8)

# %%
gamma_10 = np.power(normalized, 1.0) * 255
gamma_10 = np.clip(gamma_10, 0, 255)
gamma_10 = gamma_10.astype(np.uint8)

# %%
gamma_25 = np.power(normalized, 2.5) * 255
gamma_25 = np.clip(gamma_25, 0, 255)
gamma_25 = gamma_25.astype(np.uint8)

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,3,1)
plt.imshow(gamma_04, cmap='gray')
plt.title("Gamma 0.4 (manual)")
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(gamma_10, cmap='gray')
plt.title("Gamma 10 (manual)")
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(gamma_04, cmap='gray')
plt.title("Gamma 25 (manual)")
plt.axis('off')

plt.tight_layout()
plt.show()
