# %%
pixel1 = 45
pixel2 = 180
pixel3 = 255
print("pixel1",pixel1)
print("pixel2",pixel2)
print("pixel3",pixel3)
# Out:
# pixel1 45
# pixel2 180
# pixel3 255

# %%
pixels = [10, 90, 130, 200, 255, 5]
print(pixels[0])
print(pixels[-1])
print(pixels[2:4])
# Out:
# 10
# 5
# [130, 200]

# %%
print(max(pixels))
print(min(pixels))
print(sum(pixels) / len(pixels))
# Out:
# 255
# 5
# 115.0

# %%
varPixel = 75
if varPixel > 150: print("Bright pixel")
elif varPixel > 50: print("Medium pixel")
else: print("Dark pixel")
# Out:
# Medium pixel

# %%
for pixel in pixels:
    if pixel > 150:
        print(pixel, ": Bright pixel")
    elif pixel > 50:
        print(pixel, ": Medium pixel")
    else:
        print(pixel, ": Dark pixel")
# Out:
# 10 : Dark pixel
# 90 : Medium pixel
# 130 : Medium pixel
# 200 : Bright pixel
# 255 : Bright pixel
# 5 : Dark pixel

# %%
count = 0
for pixel in pixels:
    if pixel > 128:
        count += 1
print(count)
# Out:
# 3

# %%
def is_dark(pixel):
    return True if pixel < 50 else False
print(is_dark(10))
print(is_dark(60))
print(is_dark(120))
# Out:
# True
# False
# False

# %%
def classify_pixel(pixel):
    if pixel > 150:
        return "Bright"
    elif pixel > 50:
        return "Medium"
    else:
        return "Dark"
    
print(classify_pixel(10))
print(classify_pixel(60))
print(classify_pixel(120))
# Out:
# Dark
# Medium
# Medium
